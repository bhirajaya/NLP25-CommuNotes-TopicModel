# %%
import pandas as pd
import numpy as np
import os
import re

# %%
path = '2.politics_notes/'
df_nm = pd.read_excel(path+'nonmis_politics (1).xlsx')
df_mis = pd.read_excel(path+'mislead_politics (1).xlsx')
df_nm['Mislead_NonMislead'] = ['NonMislead']*df_nm.shape[0]
df_mis['Mislead_NonMislead'] = ['Mislead']*df_mis.shape[0]
df = pd.concat([df_nm,df_mis])

# %%
def filter_project_25(df):
  # Regular expression to match variations of "project 25"
  pattern = r"project\s*2025|proj\s*2025|p2025"  # Example: project 25, proj 25, p25
  # Use the str.contains method with the regex pattern and case-insensitive flag
  filtered_df = df[df['Document'].str.contains(pattern, case=False, regex=True)]
  return filtered_df

def filter_kamala_harris(df):
  # Regular expression to match variations of "Kamala" or "Harris"
  pattern = r"kamala|harris|Kamala|Harris"  # Example: Kamala, Harris, kamala, harris
  # Use the str.contains method with the regex pattern and case-insensitive flag
  filtered_df = df[df['Document'].str.contains(pattern, case=False, regex=True)]
  return filtered_df


def filter_immigration(df):
  # Regular expression to match variations of "immigration"
  pattern = r"immigration|immigrant|immigrants|immigrate|immigrated|immigrating"  # Example: immigration, immigrant, immigrants, immigrate etc.
  # Use the str.contains method with the regex pattern and case-insensitive flag
  filtered_df = df[df['Document'].str.contains(pattern, case=False, regex=True)]
  return filtered_df

# %%
p25_df = filter_project_25(df)
p25_df
# Out:
#       Unnamed: 0                                           Document  \
# 23           219  NN Trump has said on more than one occasion th...
# 82           629  NNN    This is personal opinion.    Also, whil...
# 91           682  NNN - Trump's claim that he doesn't know anyth...
# 122          920  NNN Trump has well established ties to authors...
# 133         1024  NNN - On page 465 of Project 2025, it calls to...
# ...          ...                                                ...
# 7577       32332  Project 2025 is a vision laid out by the Herit...
# 7753       33211  Trumps plan is called Agenda 47. He does not b...
# 7796       33648  President Trump has publicly criticized Projec...
# 8115       36552  Donald Trump has consistently stated that Proj...
# 8206       37115  Donald Trump has stated he is not affiliated w...
#
#      Mislead_NonMislead
# 23           NonMislead
# 82           NonMislead
# 91           NonMislead
# 122          NonMislead
# ...

# %%
kamala_df = filter_kamala_harris(df)
kamala_df
# Out:
#       Unnamed: 0                                           Document  \
# 61           488  NNN - She refused to do the Fox debate. When y...
# 67           555  NNN — Ultimate historical revisionism. Biden...
# 74           578  NNN, the video is factual, Kamala Harris made ...
# 76           585  NNN. This was not a commercial production but ...
# 90           680  NNN - The suggested note belongs in a comment ...
# ...          ...                                                ...
# 7887       34367  Kamala Harris is currently in office as Vice p...
# 7957       34939  The people leaving NY for PA were Harris campa...
# 8165       36916  “We are not taking anybody’s guns away,”...
# 8213       37152  OP claims that “ Kamala won EVERY SINGLE sta...
# 8215       37164  Kamala Harris is not, in fact, a communist. Sh...
#
#      Mislead_NonMislead
# 61           NonMislead
# 67           NonMislead
# 74           NonMislead
# 76           NonMislead
# ...

# %%
immi_df = filter_immigration(df)
immi_df
# Out:
#       Unnamed: 0                                           Document  \
# 192         1687  The question addressed by Capehart and Biden i...
# 239         2207  The Michigan newcomer rental subsidy would app...
# 253         2338  NNN    First it's a meme.    But CNs which sta...
# 272         2453  Illegal immigrants travel to the UK by small b...
# 288         2547  NNN - Nothing in the Wired article is refuted ...
# ...          ...                                                ...
# 8041       35780  Biden isn’t secretly flying migrants to US a...
# 8132       36749  The liberal party has been in power for 8 year...
# 8161       36897  Immigration policy is partly to blame. Canada ...
# 8185       37001  Refugees are not illegal immigrants and they e...
# 8195       37065  Fraser’s policies as immigration minister ad...
#
#      Mislead_NonMislead
# 192          NonMislead
# 239          NonMislead
# 253          NonMislead
# 272          NonMislead
# ...

# %%
# prompt: inner join on Unnamed p25 and immi df

# import pandas as pd
# Assuming p25_df and immi_df are already defined as in your provided code

# Perform the inner join
merged_df = pd.merge(p25_df, immi_df, on='Unnamed: 0', how='inner')

# Display the merged DataFrame
merged_df
# Out:
#    Unnamed: 0                                         Document_x  \
# 0        8184  OP ties her comment to the forwarded file insi...
#
#   Mislead_NonMislead_x                                         Document_y  \
# 0              Mislead  OP ties her comment to the forwarded file insi...
#
#   Mislead_NonMislead_y
# 0              Mislead

# %%
pd.merge(p25_df, kamala_df, on='Unnamed: 0', how='inner')
# Out:
#     Unnamed: 0                                         Document_x  \
# 0         1024  NNN - On page 465 of Project 2025, it calls to...
# 1         3387  President Trump, although vaguely distancing h...
# 2         5184  NNN - There is sufficient connection of Trump ...
# 3        10092  Donald Trump is a pathological liar, seen in t...
# 4        11710  Trump is leading in the polls and has been mor...
# 5        14600  Trump has repeatedly stated he has nothing to ...
# 6        15604  In the post this is directly responding to, Ka...
# 7        18401  Project 2025 derived from a Heritage Foundatio...
# 8        21715  The Harris/Walz committee is pushing propagand...
# 9        25837  Trump did not write project 2025. It was writt...
# 10       30957  Trump has explicitly denied any involvement wi...
#
#    Mislead_NonMislead_x                                         Document_y  \
# 0            NonMislead  NNN - On page 465 of Project 2025, it calls to...
# ...

# %%
pd.merge(immi_df, kamala_df, on='Unnamed: 0', how='inner')
# Out:
#     Unnamed: 0                                         Document_x  \
# 0         5329  NNN. The &quot;left&quot; is indeed facilitati...
# 1        11922  NNN. Harris' explanation is mass amnesty. We h...
# 2          301  Kamala Harris was never given a role of “bor...
# 3         2744  Kamala Harris was never given any responsibili...
# 4         3433  Kamala Harris was tasked with tackling causes ...
# 5         8753  It was widely reported in 2021 by Axios and ot...
# 6        12526  This post misleadingly equates portable fencin...
# 7        13887  Harris is not, nor ever was, a US border czar....
# 8        14615  Axios's correction was factual.  She was not n...
# 9        16309  Harris is not, nor ever was, a US border czar....
# 10       16580  Harris is not, nor ever was, a US border czar....
# 11       18498  Watch video for the full content of Eluzabeth ...
# 12       21400  1.5 million illegal immigrants a year isn't fi...
# ...

# %%
# prompt: outer join 3 df, result in 1 set of columns with data and columns indicate if in that each df

import pandas as pd
# Merge the three dataframes using outer join
merged_df = pd.merge(p25_df, immi_df, on='Unnamed: 0', how='outer', suffixes=('_p25', '_immi'))
merged_df = pd.merge(merged_df, kamala_df, on='Unnamed: 0', how='outer', suffixes=('', '_kamala'))

# Create indicator columns
merged_df['in_p25'] = merged_df['Document_p25'].notna().astype(int)
merged_df['in_immi'] = merged_df['Document_immi'].notna().astype(int)
merged_df['in_kamala'] = merged_df['Document'].notna().astype(int)

# # Select desired columns and rename for clarity
# merged_df = merged_df[['Unnamed: 0', 'Document_p25', 'Document_immi', 'Document', 'Mislead_NonMislead_p25', 'Mislead_NonMislead', 'Mislead_NonMislead_kamala',  'in_p25', 'in_immi', 'in_kamala']]
# merged_df = merged_df.rename(columns={
#     'Document_p25': 'Document_Project25',
#     'Document_immi': 'Document_Immigration',
#     'Document': 'Document_Kamala',
#     'Mislead_NonMislead_p25': 'Mislead_NonMislead_Project25',
#     'Mislead_NonMislead': 'Mislead_NonMislead_Kamala',
#     'Mislead_NonMislead_kamala': 'Mislead_NonMislead_Immigration'
# })

merged_df
# Out:
#      Unnamed: 0                                       Document_p25  \
# 0           219  NN Trump has said on more than one occasion th...
# 1           293                                                NaN
# 2           301                                                NaN
# 3           350                                                NaN
# 4           370                                                NaN
# ..          ...                                                ...
# 550       37001                                                NaN
# 551       37065                                                NaN
# 552       37115  Donald Trump has stated he is not affiliated w...
# 553       37152                                                NaN
# 554       37164                                                NaN
#
#     Mislead_NonMislead_p25                                      Document_immi  \
# 0               NonMislead                                                NaN
# ...

# %%
# prompt: merged_df reduce to 1 Document column not merge just bring 1


# Create a new 'Document' column by taking the first non-null value from the existing document columns
merged_df['Document'] = merged_df['Document_p25'].fillna(merged_df['Document_immi']).fillna(merged_df['Document'])
merged_df['Mislead_NonMislead'] = merged_df['Mislead_NonMislead_p25'].fillna(merged_df['Mislead_NonMislead_immi']).fillna(merged_df['Mislead_NonMislead'])

merged_df
# Out:
#      Unnamed: 0                                       Document_p25  \
# 0           219  NN Trump has said on more than one occasion th...
# 1           293                                                NaN
# 2           301                                                NaN
# 3           350                                                NaN
# 4           370                                                NaN
# ..          ...                                                ...
# 550       37001                                                NaN
# 551       37065                                                NaN
# 552       37115  Donald Trump has stated he is not affiliated w...
# 553       37152                                                NaN
# 554       37164                                                NaN
#
#     Mislead_NonMislead_p25                                      Document_immi  \
# 0               NonMislead                                                NaN
# ...

# %%
# Select desired columns (only one 'Document' column now)
merged_df = merged_df[['Unnamed: 0', 'Document', 'Mislead_NonMislead','in_p25', 'in_immi', 'in_kamala']]
merged_df = merged_df.rename(columns={'Unnamed: 0':'original_index'})

merged_df
# Out:
#      original_index                                           Document  \
# 0               219  NN Trump has said on more than one occasion th...
# 1               293  Noncitizens have been barred from voting in fe...
# 2               301  Kamala Harris was never given a role of “bor...
# 3               350  &quot;Haitian immigrants are eating pets in Oh...
# 4               370  Illegal border crossings have averaged 2 milli...
# ..              ...                                                ...
# 550           37001  Refugees are not illegal immigrants and they e...
# 551           37065  Fraser’s policies as immigration minister ad...
# 552           37115  Donald Trump has stated he is not affiliated w...
# 553           37152  OP claims that “ Kamala won EVERY SINGLE sta...
# 554           37164  Kamala Harris is not, in fact, a communist. Sh...
#
#     Mislead_NonMislead  in_p25  in_immi  in_kamala
# 0           NonMislead       1        0          0
# ...

# %%
merged_df.to_excel(path+'3topics_notes_details.xlsx',index=False)

# %%
merged_df = merged_df.rename(columns={'original_index':''})
merged_df[['','Document']].to_excel(path+'3topics_notes.xlsx',index=False)
